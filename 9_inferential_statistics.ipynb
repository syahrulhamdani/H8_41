# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from IPython.display import Math, Latex
from IPython.core.display import Image
from scipy.stats import uniform, norm, gamma, \
                        expon, poisson, binom, bernoulli

# seaborn config
sns.set(color_codes=True)
sns.set(rc={'figure.figsize': (5, 5)})

# %%
# !pip list | grep seaborn

# %% [markdown]
# ## Uniform Distribution

# %%
n = 1000
start = 10
width = 20
rv_uniform = uniform.rvs(size=n, loc=start, scale=width)
# rv_uniform

# %%
sns.distplot(
    rv_uniform,
    bins=100,
    kde=True,
    color='skyblue',
    hist_kws={"linewidth": 15, "alpha": 1}
)
plt.xlabel("uniform dist")
plt.ylabel("Frequency")
plt.show()
# Out:
# /Users/syahrulhamdani/.pyenv/versions/3.7.7/envs/PYTN/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Normal Distribution

# %%
n = 100
avg = 0
stdev = 1
rv_normal = norm.rvs(size=n, loc=avg, scale=stdev)
rv_normal
# Out:
# array([ 7.89090017e-01, -6.39624205e-01, -2.09027602e+00, -1.16833207e+00,
#        -7.50254597e-01,  2.95295132e-01,  1.92381605e+00, -9.54499291e-01,
#         1.70164019e+00, -2.14499396e-01, -6.61710713e-01,  9.51195778e-01,
#        -2.36492847e-06,  2.35838130e+00,  1.56439343e+00,  1.24819856e+00,
#         1.24964631e+00, -1.86012965e-01,  2.61812983e-01,  4.40205130e-02,
#         1.28030410e+00, -9.55518685e-01,  1.59544593e-01,  3.56284380e-01,
#         1.33466879e+00,  6.25485642e-01,  8.68523788e-01, -2.72272971e-01,
#        -4.90131805e-02,  1.55286986e+00,  2.25163982e+00,  3.42606199e-01,
#         1.88435505e+00, -6.76631172e-01,  1.19587923e+00,  5.50663366e-01,
#         1.34022342e-01, -9.83673956e-01,  1.75857853e+00, -5.80977119e-01,
#        -2.40975304e-01, -1.66467794e+00,  1.18175273e+00, -2.40936271e-01,
#         8.35200408e-01,  1.14981151e-02, -1.07915797e+00, -7.75163544e-01,
#        -7.51528195e-01, -4.53464678e-01,  4.22825170e-01,  9.57379243e-01,
#        -4.97617801e-01,  8.89170766e-01,  7.39316125e-02, -3.56887260e-01,
#         6.16592276e-01, -2.34381208e-01, -1.28042658e+00,  1.24162297e+00,
#        -1.13117718e+00,  4.01409593e-01, -1.24616647e+00,  1.33216301e+00,
#         1.51742053e-01,  6.19017448e-01,  5.92624285e-01, -8.83016107e-01,
#        -8.45750913e-01,  9.68536105e-01, -2.38553733e-01, -1.87449001e+00,
#         1.09333989e+00, -1.49028050e+00, -1.01872448e+00,  6.02905415e-01,
#         2.40653029e+00,  2.65644091e-02, -3.08846058e-01,  9.51249829e-01,
#         3.30252503e-01,  1.66955641e-01, -5.93662823e-01, -1.16170924e+00,
#         4.25737764e-01,  8.92370525e-01, -1.56690341e-01,  3.00429913e-01,
#        -1.01588000e+00, -3.73488123e-01, -1.36587516e+00,  8.16017690e-01,
#         2.30329934e-01,  1.06085907e+00,  1.37592849e+00, -3.99463744e-02,
#        -1.54140526e+00, -3.12738060e-01, -1.18584947e+00,  7.27243855e-01])

# %%
sns.distplot(
    rv_normal,
    bins=100,
    kde=True,
    color='skyblue',
    hist_kws={"linewidth": 15, "alpha": 1}
)
plt.xlabel("standard normal distribution")
plt.ylabel("frequency")
plt.show()
# Out:
# /Users/syahrulhamdani/.pyenv/versions/3.7.7/envs/PYTN/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Gamma Distribution

# %%
n = 1000
gamma_a = 5
rv_gamma = gamma.rvs(loc=0, scale=1, a=gamma_a, size=n)
# rv_gamma

# %%
sns.distplot(
    rv_gamma,
    bins=100,
    kde=True,
    color='skyblue',
    hist_kws={"linewidth": 15, "alpha": 1}
)
plt.xlabel("gamma distribution")
plt.ylabel("frequency")
plt.show()
# Out:
# /Users/syahrulhamdani/.pyenv/versions/3.7.7/envs/PYTN/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Exponential Distribution

# %%
n = 1000
loc = 0
scale = 1
rv_exponent = expon.rvs(loc=loc, scale=scale, size=n)

# %%
sns.distplot(
    rv_exponent,
    bins=100,
    kde=True,
    color='skyblue',
    hist_kws={"linewidth": 15, "alpha": 1}
)
plt.xlabel("exponential distribution")
plt.ylabel("frequency")
plt.show()
# Out:
# /Users/syahrulhamdani/.pyenv/versions/3.7.7/envs/PYTN/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Poisson Distribution

# %%
rv_poisson = poisson.rvs(mu=3, size=10000)

sns.distplot(
    rv_poisson,
    bins=200,
    kde=False,
    color='skyblue',
    hist_kws={"linewidth": 15, "alpha": 1}
)
plt.xlabel("poisson distribution")
plt.ylabel("frequency")
plt.show()
# Out:
# /Users/syahrulhamdani/.pyenv/versions/3.7.7/envs/PYTN/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Binomial Distribution

# %%
rv_binom = binom.rvs(n=10, p=.2, size=1000)
sns.distplot(
    rv_binom,
    bins=100,
    kde=False,
    color='skyblue',
    hist_kws={"linewidth": 15, "alpha": 1}
)
plt.xlabel("binomiial distribution")
plt.ylabel("frequency")
plt.show()

# %%
rv_binom = binom.rvs(n=10, p=.5, size=1000)
sns.distplot(
    rv_binom,
    bins=100,
    kde=False,
    color='skyblue',
    hist_kws={"linewidth": 15, "alpha": 1}
)
plt.xlabel("binomiial distribution")
plt.ylabel("frequency")
plt.show()

# %%
rv_binom = binom.rvs(n=10, p=.8, size=100)
sns.distplot(
    rv_binom,
    bins=100,
    kde=False,
    color='skyblue',
    hist_kws={"linewidth": 15, "alpha": 1}
)
plt.xlabel("binomiial distribution")
plt.ylabel("frequency")
plt.show()

# %% [markdown]
# ## Bernoulli Distribution

# %%
rv_bernoulli = bernoulli.rvs(size=1000, p=.6)
sns.distplot(
    rv_bernoulli,
    bins=100,
    kde=False,
    color='skyblue',
    hist_kws={"linewidth": 15, "alpha": 1}
)
plt.xlabel("bernoulli distribution")
plt.ylabel("frequency")
plt.show()
# Out:
# /Users/syahrulhamdani/.pyenv/versions/3.7.7/envs/PYTN/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Confidence interval

# %%
df = pd.read_csv("../data/heart.csv")
print(df.shape)
df.head()
# Out:
# (1025, 14)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df["sex_name"] = df.sex.replace({1: "male", 0: "female"})
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target sex_name
# 0   2     3       0     male
# 1   0     3       0     male
# 2   0     3       0     male
# 3   1     3       0     male
# 4   3     2       0   female

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
#  14  sex_name  1025 non-null   object
# dtypes: float64(1), int64(13), object(1)
# memory usage: 120.2+ KB

# %%
dx = df[["sex_name", "target"]]
dx
# Out:
#      sex_name  target
# 0        male       0
# 1        male       0
# 2        male       0
# 3        male       0
# 4      female       0
# ...       ...     ...
# 1020     male       1
# 1021     male       0
# 1022     male       0
# 1023   female       1
# 1024     male       0
#
# [1025 rows x 2 columns]

# %%
pd.crosstab(dx.target, dx.sex_name)
# Out:
# sex_name  female  male
# target
# 0             86   413
# 1            226   300

# %%
pop_female = 86 + 226
prop_female = 226 / pop_female
print('female population:', pop_female)
print('proportion of female having disease:', prop_female)
# Out:
# female population: 312
# proportion of female having disease: 0.7243589743589743

# %%
stderr_female = np.sqrt(
    prop_female * (1-prop_female) / pop_female
)
print("standard error for proportion:", stderr_female)
# Out:
# standard error for proportion: 0.02529714756803247

# %%
def compute_confint(estimate, stderr, z_score=1.96):
    return (
        estimate - z_score*stderr,
        estimate + z_score*stderr
    )

# %%
compute_confint(prop_female, stderr_female)
# Out:
# (0.6747765651256307, 0.773941383592318)

# %%
z_score = 1.96
lower_ci = prop_female - (z_score*stderr_female)
upper_ci = prop_female + (z_score*stderr_female)
print('CI: [{}, {}]'.format(lower_ci, upper_ci))
# Out:
# CI: [0.6747765651256307, 0.773941383592318]

# %%
# CI using statsmodels
sm.stats.proportion_confint(n * prop_female, n)
# Out:
# (0.69666425668595, 0.7520536920319987)

# %%
df.groupby("sex_name").agg(
    {"chol": [np.mean, np.std, np.size]}
)
# Out:
#                 chol
#                 mean        std size
# sex_name
# female    261.455128  64.466781  312
# male      239.237027  43.155535  713

# %%
mean_female_chol = 261.455
std_female_chol = 64.467
n_female = 312
z = 1.96

stderr_mean_female = std_female_chol / np.sqrt(n_female)
print("standard error of mean:", stderr_mean_female)
# Out:
# standard error of mean: 3.6497251780099824

# %%
lower_ci, upper_ci = compute_confint(
    estimate=mean_female_chol,
    stderr=stderr_mean_female
)
print("CI of mean estimate: [{}, {}]".format(
    lower_ci, upper_ci
))
# Out:
# CI of mean estimate: [254.30153865110043, 268.60846134889954]

# %% [markdown]
# ## Hypothesis Test

# %%
n = 1018
pnull = .52
phat = .56

# %%
sm.stats.proportions_ztest(
    phat * n,
    n,
    pnull,
    alternative="larger"
)
# Out:
# (2.571067795759113, 0.005069273865860533)
